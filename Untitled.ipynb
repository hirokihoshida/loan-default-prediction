# %%
import pandas as pd

# %%
df = pd.read_csv("sample_orig_2018.txt", sep="|")
df.columns = pd.read_csv("headers.txt", header=None)[0].tolist()
df

# %%
df = pd.read_csv("sample_svcg_2018.txt", sep="|")
df.columns = pd.read_csv("headers.txt", header=None)[0].tolist()
df
# Out:
#         Loan Sequence Number  Monthly Reporting Period  Current Actual UPB  \
# 0               F18Q10000027                    201803            74000.00
# 1               F18Q10000027                    201804            73000.00
# 2               F18Q10000027                    201805            73000.00
# 3               F18Q10000027                    201806            73000.00
# 4               F18Q10000027                    201807            73000.00
# ...                      ...                       ...                 ...
# 1215009         F18Q40289783                    202010           427073.80
# 1215010         F18Q40289783                    202011           426312.82
# 1215011         F18Q40289783                    202012           425549.88
# 1215012         F18Q40289821                    202011           420000.00
# 1215013         F18Q40289821                    202012           420000.00
#
#         Current Loan Delinquency Status  Loan Age  \
# ...

# %%
df['Current Loan Delinquency Status'] = df['Current Loan Delinquency Status'].replace('R', 100).astype(int)
df
# Out:
#         Loan Sequence Number  Monthly Reporting Period  Current Actual UPB  \
# 0               F18Q10000027                    201803            74000.00
# 1               F18Q10000027                    201804            73000.00
# 2               F18Q10000027                    201805            73000.00
# 3               F18Q10000027                    201806            73000.00
# 4               F18Q10000027                    201807            73000.00
# ...                      ...                       ...                 ...
# 1215009         F18Q40289783                    202010           427073.80
# 1215010         F18Q40289783                    202011           426312.82
# 1215011         F18Q40289783                    202012           425549.88
# 1215012         F18Q40289821                    202011           420000.00
# 1215013         F18Q40289821                    202012           420000.00
#
#          Current Loan Delinquency Status  Loan Age  \
# ...

# %%
df.head(100)
# Out:
#    Loan Sequence Number  Monthly Reporting Period  Current Actual UPB  \
# 0          F18Q10000027                    201803            74000.00
# 1          F18Q10000027                    201804            73000.00
# 2          F18Q10000027                    201805            73000.00
# 3          F18Q10000027                    201806            73000.00
# 4          F18Q10000027                    201807            73000.00
# ..                  ...                       ...                 ...
# 95         F18Q10000116                    201911            25814.35
# 96         F18Q10000116                    201912            25751.75
# 97         F18Q10000116                    202001            25688.92
# 98         F18Q10000116                    202002            25625.87
# 99         F18Q10000116                    202003            25562.60
#
#     Current Loan Delinquency Status  Loan Age  \
# 0                                 0         1
# ...

# %%
df['Current Loan Delinquency Status'].replace('R', 100).astype(int).value_counts()
# Out:
# 0      1190434
# 1        10419
# 2         3916
# 3         2659
# 4         1935
# 5         1609
# 6         1231
# 7          973
# 8          749
# 9          495
# 10         156
# 11          93
# 12          69
# 13          55
# 14          46
# 15          39
# 16          34
# 17          32
# 18          20
# 100         12
# 19          10
# 20           8
# 21           6
# 22           4
# 23           3
# 24           3
# 28           1
# 25           1
# 26           1
# 27           1
# Name: Current Loan Delinquency Status, dtype: int64

# %%
df['Current Loan Delinquency Status']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-391bcc90e9a1> in <module>
# ----> 1 df['Current Loan Delinquency Status'].astype(int).value_counts().index
#
# c:\users\hiroki\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# c:\users\hiroki\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# ...

# %%
df['Current Loan Delinquency Status'].value_counts()
# Out:
# 0     997404
# 0     193030
# 1       8774
# 2       3387
# 3       2304
# 4       1665
# 1       1645
# 5       1383
# 6       1059
# 7        836
# 8        650
# 2        529
# 9        430
# 3        355
# 4        270
# 5        226
# 6        172
# 10       138
# 7        137
# 8         99
# 11        81
# 9         65
# 12        60
# 13        47
# 14        39
# 15        34
# 17        31
# 16        30
# 18        19
# 10        18
# 11        12
# R         12
# 12         9
# 19         9
# 13         8
# 14         7
# 20         7
# 21         5
# 15         5
# 22         4
# 16         4
# 23         3
# 24         3
# 26         1
# 27         1
# 28         1
# 20         1
# 17         1
# 21         1
# 18         1
# 19         1
# 25         1
# Name: Current Loan Delinquency Status, dtype: int64

# %%
df = pd.read_csv("sample_svcg_2018.txt", sep="|")
df.columns = pd.read_csv("headers.txt", header=None)[0].tolist()
df
# Out:
# c:\users\hiroki\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (3,7,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-7d7697ee73a1> in <module>
#       1 df = pd.read_csv("sample_svcg_2018.txt", sep="|")
# ----> 2 df.columns = pd.read_csv("headers.txt", header=None)[0].tolist()
#       3 df
#
# c:\users\hiroki\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# ...

# %%
pd.read_csv("sample_orig_2018.txt", sep="|")
# Out:
#         784  201803  9  204802    49180  000  1  I  75  39  ...  360  01  \
# 0       693  201803  N  203302  24340.0    0  1  P  80  41  ...  180   2
# 1       731  201803  9  204802      NaN    0  1  P  45  37  ...  360   1
# 2       763  201802  Y  204801      NaN   30  1  P  95  34  ...  360   1
# 3       755  201803  9  204802  49700.0    0  1  P  80  33  ...  360   2
# 4       728  201803  9  204802      NaN    0  1  P  80  44  ...  360   1
# ...     ...     ... ..     ...      ...  ... .. ..  ..  ..  ...  ...  ..
# 49994  9999  202001  9  204912      NaN    0  1  P  80  20  ...  360   2
# 49995   811  202003  9  204912      NaN    0  1  P  52  34  ...  358   2
# 49996   809  202008  9  204907  19660.0    0  1  P  77  23  ...  348   1
# 49997   756  202007  9  204912      NaN    0  1  S  51  50  ...  354   2
# 49998   767  202102  9  205101      NaN    0  1  P  80  32  ...  360   1
#
#         Other sellers  Other servicers Unnamed: 25 Unnamed: 26 9.1  \
# ...
